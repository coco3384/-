# %%
import numpy as np
import pandas as pd

# %%
def read_csv(csv_list):
    output = pd.DataFrame()
    for csv in csv_list:
        df = pd.read_csv(csv)
        output = pd.concat([output, df])
    output.reset_index(drop=True, inplace=True)
    return output

def load_database():
    # all the ortho filenames
    ortho_df = read_csv(['ortho1200_all.csv'])
    ortho_df['label'] = [False for i in range(len(ortho_df))]
    ortho_df.columns = ortho_df.columns.str.replace('現有檔名', 'NAME')
    ortho_df.NAME = ortho_df.apply(lambda x: x.NAME.split('.')[0], axis=1)
    ortho_df['CloudRate'] = ortho_df['CloudRate'].apply(lambda x: x // 10)
    ortho_df['secret'] = ortho_df.apply(lambda x: x.NAME[-1] == 'c', axis=1)
    # all the DMC filenames
    aerial_df = read_csv(['DMC2021_pick_all.csv', 'DMC3_with_quality.csv'])
    aerial_df['label'] = [False for i in range(len(aerial_df))]
    aerial_df['NAME'] = aerial_df.apply(lambda x: x.filename if isinstance(x.filename, str) else x['name'], axis=1)
    aerial_df['secret'] = aerial_df.apply(lambda x: x.NAME[-1] == 'c', axis=1)
    aerial_df.NAME = aerial_df.apply(lambda x: x.NAME.split('.')[0], axis=1)
    return {'ortho': ortho_df[['NAME', 'CloudRate', 'secret', 'label']], 'DMC': aerial_df[['NAME', 'QUALITY', 'secret', 'label']]}

# %%
def take_data_you_have(path, type):
    # load database
    database = load_database()[type]
    
    # read your fileList
    with open(path, 'r') as f:
        file_list = f.readlines()
    name_list = []
    for file in file_list:
        if file.split('.')[-1] in ['png\n', 'tif\n', 'jpg\n', 'jpeg\n', 'tiff\n']:
            if type == 'ortho':
                name_list.append(file.split('.')[0])
            elif type == 'DMC':
                name = file.split('.')[0].split('_')[0] + '_' + file.split('.')[0].split('_')[1]
                name_list.append(name)
    mask = []
    for name in database.NAME:
        mask.append(name in name_list)
    return database[mask].reset_index()    

path = input('path to your list:')
type = input('ortho or DMC')
take_data_you_have(path, type)
# Out:
# path to your list: FileNames_冠均.txt
# ortho or DMC DMC
# ['210102e_24~0324', '210102e_24~0331', '210102e_24~0332', '210102e_24~0333', '210102e_24~0336', '210102e_24~0337', '210102e_26~0352', '210102e_26~0363', '210102e_26~0370', '210102e_26~0372', '210102e_26~0381', '210102e_26~0405', '210102e_33~0190', '210102e_33~0191', '210102e_33~0201', '210102e_33~0210', '210102e_34~0087', '210102e_34~0088', '210102e_34~0089', '210102e_34~0106', '210102e_34~0122', '210102e_34~0129', '210102g_31~0162', '210102g_31~0170', '210102g_31~0177', '210104d_40~0058', '210104d_40~0065', '210104d_40~0069', '92202070_090213', '93203024_090213', '93203052_210129k', '93203053_120323k', '93203065_140728k', '93203072_210129k', '93203085_180312k', '93204085_210129k', '93204094_180312k', '94171005_120922a', '94171019_140514a', '94171040_150919b', '94181002_150924a', '94181005_150416a', '94181006_191130', '94181010_160626d', '94181014_160918a', '94181023_120413a', '94181024_090910', '94181025_090331a', '94181026_180606', '94181027_150416a', '94181029_121014a', '94181031_150924a', '94181035_170430', '94181037_170923', '94181038_170923', '94181039_150923a', '94181044_150924a', '94181051_130908a', '94181053_160423a', '94181056_080907a', '94181059_120902a', '94181060_090907', '94181063_140514a', '94181065_150923a', '94181072_160423a']
#     index             NAME QUALITY  secret  label
# 0       0  210102e_34~0087       b   False  False
# 1       1  210102e_34~0088       b   False  False
# 2       2  210102e_34~0089       b   False  False
# 3       3  210102e_34~0106       a   False  False
# 4       4  210102e_34~0122       a   False  False
# 5       5  210102e_34~0129       a   False  False
# 6       6  210102e_33~0190       b   False  False
# 7       7  210102e_33~0191       b   False  False
# 8       8  210102e_33~0201       a   False  False
# 9       9  210102e_33~0210       a   False  False
# 10     10  210102e_24~0324       a   False  False
# 11     11  210102e_24~0331       b   False  False
# 12     12  210102e_24~0332       b   False  False
# 13     13  210102e_24~0333       b   False  False
# 14     14  210102e_24~0336       a   False  False
# 15     15  210102e_24~0337       a   False  False
# 16     16  210102e_26~0352       b   False  False
# 17     17  210102e_26~0363       a   False  False
# 18     18  210102e_26~0370       b   False  False
# 19     19  210102e_26~0372       b   False  False
# 20     20  210102e_26~0381       a   False  False
# 21     21  210102e_26~0405       a   False  False
# 22     28  210102g_31~0162       a   False  False
# 23     29  210102g_31~0170       a   False  False
# 24     30  210102g_31~0177       a   False  False
# 25     48  210104d_40~0058       b   False  False
# 26     49  210104d_40~0065       a   False  False
# 27     50  210104d_40~0069       a   False  False
